# %% [markdown]
# <a href="https://colab.research.google.com/github/Iambinhh/Homework_week_7/blob/main/Week_7_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data= pd.read_csv("1.01. Simple linear regression.csv")
x1=np.array(data['SAT'])
y=np.array(data['GPA'])
plt.scatter(x1,y)
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()
data.hist()
plt.show()
correlation= data.corr()
print(correlation)
# Out:
#           SAT       GPA
# SAT  1.000000  0.637184
# GPA  0.637184  1.000000

# %%
url='mtcars.csv'
data= pd.read_csv(url)
data.hist()
plt.show()
correlation= data.corr()
print(correlation)
X=data.drop(data.columns[[0,2]],axis=1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='grey')
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
from sklearn import  linear_model# import thu vien sklearn nham de machien tu hoc duoc, voi phan linear_model nham de the hien duong phan linear_model
model=linear_model.LinearRegression()#tao ham hi quy tuyen tinh
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])#nhap cac du lieu cua data bao gom "wt" va "mpg"
print(model.intercept_)#gia tri trung binh khi ta cho cac bien du doan cua ham hoi quy tuyen tinh bang khong.
print(model.coef_)

print(model.score(pd.DataFrame(data['wt']),data['mpg']))
y_pred= model.predict(pd.DataFrame(data['wt']))
residual= data['mpg'] - y_pred#sai so giua du lieu goc va du lieu duoc du doan
residual.describe()
print(data['mpg'],end=' ')
print(y_pred,end=' ')
print(residual,end=' ')

data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red')
plt.plot(data['wt'],y_pred,color='blue')
# Out:
# 37.28512616734204
# [-5.34447157]
# 0.7528327936582646
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64 [23.28261065 21.9197704  24.88595212 20.10265006 18.90014396 18.79325453
#  18.20536265 20.23626185 20.45004071 18.90014396 18.90014396 15.53312687
#  17.3502472  17.08302362  9.22665041  8.29671236  8.71892561 25.52728871
#  28.65380458 27.47802083 24.11100374 18.47258623 18.92686632 16.76235533
#  16.73563297 26.94357367 25.847957   29.19894068 20.34315128 22.48093991
#  18.20536265 22.4274952 ] 0    -2.282611
# 1    -0.919770
# 2    -2.085952
# 3     1.297350
# 4    -0.200144
# ...

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**2]).T
y=data['mpg']
model.fit(X,y=data['mpg'])
print("Intercpet of model two degrees:")
print(model.intercept_)
print('Cofienct of model two degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1.5,5.5,0.1)#do phan wt tropng du lieu chi trong khoang tu [0,5.5] nen ta se su dung mot ham range voi khoang nhu vat
predictor=pd.DataFrame([range,range**2]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercpet of model two degrees:
# 49.93081094945181
# Cofienct of model two degrees:
# [-13.38033708   1.17108689]
# The accuracy of the model
# 0.8190613581384094
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
print("Intercpet of model tenth degrees:")
print(model.intercept_)
print('Cofienct of model tenth degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercpet of model tenth degrees:
# -14921.11995188375
# Cofienct of model tenth degrees:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# The accuracy of the model
# 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X=[]  
X=pd.DataFrame([])
for i in range(1,3):
  
  X.append([data['wt']**i]).T
model.fit(X,y=data['mpg'])
print("Intercpet of model tenth degrees:")
print(model.intercept_)
print('Cofienct of model tenth degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-da6dd74b7fdf> in <module>
#       2 X=[]
#       3 X=pd.DataFrame([])
# ----> 4 for i in range(1,3):
#       5
#       6   X.append([data['wt']**i]).T
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import seaborn as sns
data=pd.read_csv("50_Startups.csv")
data.head()

sns.pairplot(data)
X=data.drop('Profit',axis=True)#delete of column Profit values
X=data.drop('State',axis=True)#delete one more column State cause it is string
y=data['Profit']
X.head()

from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
sc=StandardScaler()
X=sc.fit_transform(X)

from sklearn.model_selection import train_test_split# chia du lieu thanh cac phan train va test


X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=0)
#url: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40, 4)
# (10, 4)
# (40,)
# (10,)

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
#Starting machine learning

regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_pred= regressor.predict(X_test).round(1)#prediction with rouding one num after comma
calculation=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profits','Predicted Profit'])

print(regressor.score(X_test, y_test))

print(regressor.score(X_train,y_train))
# Out:
# 1.0
# 1.0

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_1=pd.read_csv("Advertising.csv")
data_1.head()

sns.pairplot(data_1)

# %%
corr=data_1.corr()

sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
from sklearn import  linear_model# import thu vien sklearn nham de machien tu hoc duoc, voi phan linear_model nham de the hien duong phan linear_model

from sklearn.linear_model import LinearRegression


model=linear_model.LinearRegression()
X= pd.DataFrame([data_1['TV'],data_1['TV']**2,data_1['TV']**3,data_1['TV']**4,data_1['TV']**5,data_1['TV']**6,data_1['TV']**7,data_1['TV']**8,data_1['TV']**9,data_1['TV']**10]).T
y=data_1['sales']
model.fit(X,y=data_1['sales'])
print("Intercept of model two degrees:")
print(model.intercept_)
print('Cofienct of model two degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1.5,300,0.1)
predictor=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred= model.predict(X=predictor)
data_1.plot(kind='scatter',x='TV',y='sales',figsize=(9,9),color='black')
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept of model two degrees:
# 8.856012015031148
# Cofienct of model two degrees:
# [ 3.67428628e-21 -1.24485114e-15  5.29003878e-17  4.68826381e-15
#   3.31590515e-13  1.42767664e-11 -2.19268494e-13  1.27834549e-15
#  -3.33369736e-18  3.26971648e-21]
# The accuracy of the model
# 0.5811292950059974
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# Socical_network
# USA_housing
# issurance

# %%
#SOCIAL_NETWORK_USA
import pandas as pd
import numpy as np

data= pd.read_csv("/content/Social_Network_Ads.csv")
data.head()
sns.pairplot(data)

# %%
correlation=data.corr()
print(correlation)
sns.heatmap(correlation,annot=True)
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
sc=StandardScaler()
X=sc.fit_transform(X)

from sklearn.model_selection import train_test_split# chia du lieu thanh cac phan train va test


X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=10)
#url: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-3251a74912a2> in <module>
#       1 from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
#       2 sc=StandardScaler()
# ----> 3 X=sc.fit_transform(X)
#       4
#       5 from sklearn.model_selection import train_test_split# chia du lieu thanh cac phan train va test
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
# ...

# %%
from sklearn import  linear_model# import thu vien sklearn nham de machien tu hoc duoc, voi phan linear_model nham de the hien duong phan linear_model
from sklearn.linear_model import LinearRegression
#Starting machine learning

regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_pred= regressor.predict(X_test).round(1)#prediction with rouding one num after comma
calculation=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Purchase','Predicted Age'])

print(regressor.score(X_test, y_test))

print(regressor.score(X_train,y_train))
# Out:
# 1.0
# 1.0

# %%
model=linear_model.LinearRegression()
X= pd.DataFrame([data['Age'],data['Age']**2,data['Age']**3,data['Age']**4,data['Age']**5,data['Age']**6,data['Age']**7,data['Age']**8,data['Age']**9,data['Age']**10]).T
y=data['Purchased']
model.fit(X,y=data['Purchased'])
print("Intercept of model two degrees:")
print(model.intercept_)
print('Cofienct of model two degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1.5,50,0.1)
predictor=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='Age',y='Purchased',figsize=(9,9),color='black')
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept of model two degrees:
# 1.9577088088011987
# Cofienct of model two degrees:
# [-1.33145348e-07 -2.25147952e-06 -4.08702853e-05 -2.80115564e-04
#   3.59282500e-05 -1.92491783e-06  5.49043984e-08 -8.75786859e-10
#   7.39131443e-12 -2.57611540e-14]
# The accuracy of the model
# 0.4407628028693059
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# #HOUSING SURVEY

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= pd.read_csv("/content/Housing.csv")
data.head()
sns.pairplot(data)

# %%
corr=data.corr()

sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X=data.drop('Gender',axis=True)
y=data['price']
X.head()

from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
sc=StandardScaler()
X=sc.fit_transform(X)


X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=10)
#url: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea
# 0              no             yes        2      yes
# 1              no             yes        3       no
# 2              no              no        2      yes
# 3              no             yes        3      yes
# 4              no             yes        2       no
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b2a5f7102b19> in <module>
# ...

# %%
model=linear_model.LinearRegression()

X= pd.DataFrame([data['area'],data['area']**2,data['area']**3,data['area']**4,data['area']**5,data['area']**6,data['area']**7,data['area']**8,data['area']**9,data['area']**10,data['area']**11,data['area']**12,data['area']**13,data['area']**14,data['area']**15,data['area']**16,data['area']**17,data['area']**18,data['area']**19,data['area']**20]).T
y=data['price']
model.fit(X,y=data['price'])
print("Intercept of tenth degree:")
print(model.intercept_)
print('Cofienct of model tenth degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(1000,150000,1)
predictor=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11,range**12,range**13,range**14,range**15,range**16,range**17,range**18,range**19,range**20]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='area',y='price',figsize=(9,9),color='black',xlim=(0,15000),ylim=(0,15000000))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept of tenth degree:
# 2084011.0588160283
# Cofienct of model tenth degrees:
# [ 4.97210746e-05  2.29914631e-01 -2.81687327e-05  9.52875540e-10
#  -3.01184563e-16  1.96340246e-14 -2.47446417e-14 -3.31478640e-15
#  -1.16382854e-14  2.23977499e-14 -1.46076681e-14  1.00704183e-14
#   4.03884095e-15  1.45744493e-14  3.30550407e-14  1.84733140e-14
#   3.64520495e-14  4.61436445e-15 -1.07830411e-14 -2.62290190e-15]
# The accuracy of the model
# 0.3741499902760622
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
data=pd.read_csv("/content/insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.pairplot(data, size=2.5)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
corr=data.corr()

sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X=data.drop('sex',axis='columns')
X=data.drop('region',axis='columns')
X=data.drop('smoker',axis='columns')
y=data['charges']


from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
sc=StandardScaler()
X=sc.fit_transform(X)


X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=10)
#url: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-64275f317d8e> in <module>
#       7 from sklearn.preprocessing import StandardScaler#Scale cac so nho len thanh cac gia tri phu hop cho may hoc
#       8 sc=StandardScaler()
# ----> 9 X=sc.fit_transform(X)
#      10
#      11
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
model=linear_model.LinearRegression()

X= pd.DataFrame([data['charges'],data['charges']**2,data['charges']**3,data['charges']**4]).T
y=data['age']
model.fit(X,y=data['age'])
print("Intercept of tenth degree:")
print(model.intercept_)
print('Cofienct of model tenth degrees:')
print(model.coef_)
print('The accuracy of the model')
print(model.score(X,y))
#--------------------------
range=np.arange(0,50000,1)
predictor=pd.DataFrame([range,range**2,range**3,range**4]).T
y_pred= model.predict(X=predictor)
data.plot(kind='scatter',x='charges',y='age',figsize=(9,9),color='black',xlim=(0,50000),ylim=(0,100))
plt.plot(range,y_pred,color='red')
# Out:
# Intercept of tenth degree:
# 3.303433683236129
# Cofienct of model tenth degrees:
# [ 8.86005365e-03 -5.54698255e-07  1.26612497e-11 -9.40375978e-17]
# The accuracy of the model
# 0.544474278954871
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
